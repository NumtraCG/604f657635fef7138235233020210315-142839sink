# %% [markdown]
# ***GENERATED CODE FOR sink PIPELINE.***

# %% [markdown]
# ***DON'T EDIT THIS CODE.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO READ DATA.***

# %% [markdown]
# ***CONNECTOR FUNCTIONS TO WRITE DATA.***

# %%
import datetime
import requests
import datetime
import logging
import warnings
warnings.filterwarnings('ignore')
logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.INFO)


class NumtraConnector:

    def put(inStages, inStagesData, stageId, spark, config):
        path = eval(config)['server_url']
        baseType = eval(config)['baseType']
        results_url = eval(config)['results_url']
        server = eval(config)['server']
        originalfile = eval(config)['orignalKey']
        eval(config)['pathOnly']
        filename = eval(config)['filename']
        eval(config)['ser']
        eval(config)['user']
        eval(config)['password']
        eval(config)['authSource']
        eval(config)['user_id']
        eval(config)['parent_id']
        eval(config)['project_id']
        time = str(int(datetime.datetime.now().timestamp()))

        inStagesData[inStages[0]]

        print(path)
        print(baseType)
        print(results_url)
        print(server)
        print(originalfile)
        print(filename)

        args = {
            'url': path,
            'baseType': baseType,
            'originalfile': originalfile,
            'filename': time + filename
        }

        response = requests.post(results_url, args)
        return response

# %% [markdown]
# ***READING DATAFRAME***

# %%
#%run sinkHooks.ipynb
try:
	#sourcePreExecutionHook()

	testsink = HDFSConnector.fetch(spark, "{'url': '/FileStore/platform/uploadedSourceFiles/1615367645testsink.csv', 'file_type': 'Delimeted', 'delimiter': ',', 'is_header': 'Use Header Line', 'FilePath': '/Testing schedule/testsink.csv', 'filename': '1615367645testsink.csv', 'viewFileName': 'testsink.csv', 'results_url': 'http://localhost:4040/api/read/hdfs'}")

except Exception as ex: 
	logging.error(ex)

# %% [markdown]
# ***WRITING DATAFRAME***

# %%
#%run sinkHooks.ipynb
try:
	#sinkPreExecutionHook()

	azka = NumtraConnector.fetch(spark, "{'samplefile': '/FileStore/platform/sampleData/604f6ec93f8c961e972cbf66/part-00000-ba7241cd-08d2-4450-8378-0a8a977afc40-c000.csv', 'samplecount': 26, 'originalcount': 26, 'orignalKey': '/FileStore/platform/uploadedSourceFiles/1615367645testsink.csv', 'pathOnly': '/Azka', 'project_id': '604b3df2d777a79178d4b93f', 'parent_id': '604b3df2d777a79178d4b93f', 'original_schema': [{'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf80', 'field': 'State', 'alias': 'State', 'position': '1', 'type': 'State'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf81', 'field': 'Account_Length', 'alias': 'Account_Length', 'position': '2', 'type': 'Account_Length'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf82', 'field': 'Area_Code', 'alias': 'Area_Code', 'position': '3', 'type': 'Area_Code'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf83', 'field': 'Phone', 'alias': 'Phone', 'position': '4', 'type': 'Phone'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf84', 'field': 'Intl_Plan', 'alias': 'Intl_Plan', 'position': '5', 'type': 'Intl_Plan'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf85', 'field': 'VMail_Plan', 'alias': 'VMail_Plan', 'position': '6', 'type': 'VMail_Plan'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf86', 'field': 'VMail_Message', 'alias': 'VMail_Message', 'position': '7', 'type': 'VMail_Message'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf87', 'field': 'Day_Mins', 'alias': 'Day_Mins', 'position': '8', 'type': 'Day_Mins'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf88', 'field': 'Day_Calls', 'alias': 'Day_Calls', 'position': '9', 'type': 'Day_Calls'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf89', 'field': 'Day_Charge', 'alias': 'Day_Charge', 'position': '10', 'type': 'Day_Charge'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf8a', 'field': 'Eve_Mins', 'alias': 'Eve_Mins', 'position': '11', 'type': 'Eve_Mins'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf8b', 'field': 'Eve_Calls', 'alias': 'Eve_Calls', 'position': '12', 'type': 'Eve_Calls'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf8c', 'field': 'Eve_Charge', 'alias': 'Eve_Charge', 'position': '13', 'type': 'Eve_Charge'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf8d', 'field': 'Night_Mins', 'alias': 'Night_Mins', 'position': '14', 'type': 'Night_Mins'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf8e', 'field': 'Night_Calls', 'alias': 'Night_Calls', 'position': '15', 'type': 'Night_Calls'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf8f', 'field': 'Night_Charge', 'alias': 'Night_Charge', 'position': '16', 'type': 'Night_Charge'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf90', 'field': 'Intl_Mins', 'alias': 'Intl_Mins', 'position': '17', 'type': 'Intl_Mins'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf91', 'field': 'total_Mins', 'alias': 'total_Mins', 'position': '18', 'type': 'total_Mins'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf92', 'field': 'Intl_Calls', 'alias': 'Intl_Calls', 'position': '19', 'type': 'Intl_Calls'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf93', 'field': 'Intl_Charge', 'alias': 'Intl_Charge', 'position': '20', 'type': 'Intl_Charge'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf94', 'field': 'Total_Charge', 'alias': 'Total_Charge', 'position': '21', 'type': 'Total_Charge'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf95', 'field': 'CustServ_Calls', 'alias': 'CustServ_Calls', 'position': '22', 'type': 'CustServ_Calls'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf96', 'field': 'Churn', 'alias': 'Churn', 'position': '23', 'type': 'Churn'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf97', 'field': 'cluster_labels', 'alias': 'cluster_labels', 'position': '24', 'type': 'cluster_labels'}], 'actual_schema': [{'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf68', 'field': 'State', 'alias': 'State', 'position': '1', 'type': 'State'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf69', 'field': 'Account_Length', 'alias': 'Account_Length', 'position': '2', 'type': 'Account_Length'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf6a', 'field': 'Area_Code', 'alias': 'Area_Code', 'position': '3', 'type': 'Area_Code'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf6b', 'field': 'Phone', 'alias': 'Phone', 'position': '4', 'type': 'Phone'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf6c', 'field': 'Intl_Plan', 'alias': 'Intl_Plan', 'position': '5', 'type': 'Intl_Plan'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf6d', 'field': 'VMail_Plan', 'alias': 'VMail_Plan', 'position': '6', 'type': 'VMail_Plan'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf6e', 'field': 'VMail_Message', 'alias': 'VMail_Message', 'position': '7', 'type': 'VMail_Message'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf6f', 'field': 'Day_Mins', 'alias': 'Day_Mins', 'position': '8', 'type': 'Day_Mins'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf70', 'field': 'Day_Calls', 'alias': 'Day_Calls', 'position': '9', 'type': 'Day_Calls'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf71', 'field': 'Day_Charge', 'alias': 'Day_Charge', 'position': '10', 'type': 'Day_Charge'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf72', 'field': 'Eve_Mins', 'alias': 'Eve_Mins', 'position': '11', 'type': 'Eve_Mins'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf73', 'field': 'Eve_Calls', 'alias': 'Eve_Calls', 'position': '12', 'type': 'Eve_Calls'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf74', 'field': 'Eve_Charge', 'alias': 'Eve_Charge', 'position': '13', 'type': 'Eve_Charge'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf75', 'field': 'Night_Mins', 'alias': 'Night_Mins', 'position': '14', 'type': 'Night_Mins'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf76', 'field': 'Night_Calls', 'alias': 'Night_Calls', 'position': '15', 'type': 'Night_Calls'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf77', 'field': 'Night_Charge', 'alias': 'Night_Charge', 'position': '16', 'type': 'Night_Charge'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf78', 'field': 'Intl_Mins', 'alias': 'Intl_Mins', 'position': '17', 'type': 'Intl_Mins'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf79', 'field': 'total_Mins', 'alias': 'total_Mins', 'position': '18', 'type': 'total_Mins'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf7a', 'field': 'Intl_Calls', 'alias': 'Intl_Calls', 'position': '19', 'type': 'Intl_Calls'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf7b', 'field': 'Intl_Charge', 'alias': 'Intl_Charge', 'position': '20', 'type': 'Intl_Charge'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf7c', 'field': 'Total_Charge', 'alias': 'Total_Charge', 'position': '21', 'type': 'Total_Charge'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf7d', 'field': 'CustServ_Calls', 'alias': 'CustServ_Calls', 'position': '22', 'type': 'CustServ_Calls'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf7e', 'field': 'Churn', 'alias': 'Churn', 'position': '23', 'type': 'Churn'}, {'checked': True, 'inherited': True, 'is_categorical': False, 'bad_values': '', 'nullable': 'true', '_id': '604f6ee33f8c961e972cbf7f', 'field': 'cluster_labels', 'alias': 'cluster_labels', 'position': '24', 'type': 'cluster_labels'}], 'server': 'http://216.168.41.46:3201', 'server_url': '/numtraPlatform/NumtraPlatformV2/uploads/platform/', 'delimiter': ',', 'file_type': 'Delimeted', 'filename': 'tesssst.csv', 'is_header': 'Use Header Line', 'results_url': 'http://localhost:4040/api/read/hdfs'}")

except Exception as ex: 
	logging.error(ex)
